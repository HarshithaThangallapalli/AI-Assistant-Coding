# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshithaThangallaplli/AI-Assistant-Coding/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1, -2, 3, -4, 5, -6, 0, 7, -8]
positive_numbers = [num for num in numbers if num >= 0]
print(positive_numbers)
# Out:
# [1, 3, 5, 0, 7]
